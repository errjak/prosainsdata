# %% [markdown]
# # Tugas 1 (Crawling Data dari Portal Tugas Akhir Trunojoyo)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

pta = []

for i in range(0,173):
  URL = "https://pta.trunojoyo.ac.id/c_search/byprod/10/" + str(i+1)
  r = requests.get(URL)
  soup = BeautifulSoup(r.text, 'html.parser')
  items = soup.find('div', {'id':'content_journal'})

  for it in items.findAll('li',{'data-cat':'#luxury'}):
    tempNama = it.span.text.strip('\n').replace('Penulis : ', '')
    # links = it.findAll('div', {'style':'margin: 25px 0px 15px 0px;'})
    link = it.find('a', 'gray button')['href']
    req = requests.get(link)
    soup2 = BeautifulSoup(req.text, 'html.parser')
    abstraks = soup2.findAll('div', {'style':'margin: 15px 15px 15px 15px;'})
    abstrak = soup2.find('p', {'align':'justify'}).text
  
    tempNIM = link.replace('https://pta.trunojoyo.ac.id/welcome/detail/', '')

    pta.append([it.a.text.strip('\n'), tempNIM, tempNama, abstrak])
    
pta_df = pd.DataFrame(pta, columns=['Judul', 'NIM', 'Penulis', 'Abstrak'])
pta_df
# Out:
#                                                  Judul           NIM  \
# 0    PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE \...  040411100468
# 1    APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...  040411100476
# 2    RANCANG BANGUN APLIKASI PROXY SERVER UNTUK\r\n...  040411100480
# 3    SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...  070411100070
# 4    SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...  080411100115
# ..                                                 ...           ...
# 853  PENERAPAN ALGORITMA LONG-SHORT TERM MEMORY UNT...  160411100032
# 854  SISTEM PENCARIAN TEKS AL-QURAN TERJEMAHAN BERB...  160411100182
# 855  KLASIFIKASI KOMPLEKSITAS VISUAL CITRA SAMPAH M...  160411100077
# 856  IDENTIFIKASI BINER ATRIBUT PEJALAN KAKI MENGGU...  160411100084
# 857  DETEKSI OBJEK MANUSIA BERBASIS ONE STAGE DETEC...  160411100044
#
#                      Penulis  \
# 0         A.Ubaidillah S.Kom
# 1        M. Basith Ardianto,
# 2      Akhmad Suyandi, S.Kom
# 3            Heri Supriyanto
# 4       Septian Rahman Hakim
# ..                       ...
# 853    Rachmad Agung Pambudi
# 854         Nadila Hidayanti
# 855             Afni Sakinah
# 856  Friska Fatmawatiningrum
# 857              Dian Wibowo
#
#                                                Abstrak
# 0    Sistem  informasi  akademik  (SIAKAD) merupaka...
# 1    Berjalannya koneksi jaringan komputer dengan l...
# 2    Web server adalah sebuah perangkat lunak serve...
# 3    Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 4    Seiring perkembangan teknologi yang ada diduni...
# ..                                                 ...
# 853  Investasi saham selama ini memiliki resiko ker...
# 854  Information Retrieval (IR) merupakan pengambil...
# 855  Klasifikasi citra merupakan proses pengelompok...
# 856  Identifikasi atribut pejalan kaki merupakan sa...
# 857  Topik deteksi objek telah menarik perhatian ya...
#
# [858 rows x 4 columns]

# %%
pta_df.to_csv('pta.csv', index=False)
