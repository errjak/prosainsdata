# %% [markdown]
# # Tugas 1 (Crawling Data dari Twitter Dengan Kata Kunci Ridwan Kamil)

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Run the pip install command below if you don't already have the library
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Setting variables to be used below
maxTweets = 1000

# Creating list to append tweet data to
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Ridwan Kamil since:2022-08-01 until:2023-02-20').get_items()):
    if i>maxTweets:
        break
    tweets_list1.append([tweet.user.username, tweet.content, tweet.user.location])
# Out:
# <ipython-input-8-f96e74680c4b>:11: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list1.append([tweet.user.username, tweet.content, tweet.user.location])

# %%
# Creating a dataframe from the tweets list above
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Akun Tweet', 'Tweet', 'Location'])

# Display first 5 entries from dataframe
tweets_df1
# Out:
#            Akun Tweet                                              Tweet  \
# 0            AldiNeno  Lucky Hakim mengungkapkan rasa senangnya dalam...
# 1          fikri_arif  @RokiDermawan @toptobs @OfficialVBogor Saya be...
# 2     Adityasaputrooo  SPIN mengajukan pertanyaan jika pemilihan pres...
# 3     Adityasaputrooo  Gubernur Jabar @ridwankamil mengatakan saat in...
# 4     Adityasaputrooo  "Ini adalah arahan Pak Jokowi untuk memulai pe...
# ...               ...                                                ...
# 996          detikcom  Bupati Bandung Dadang Supriatna meminta Ridwan...
# 997        jhenyfer_c  Pilkada Jabar, Ridwan Kamil: Semua Saya Doakan...
# 998          sifoelan  Pilkada Jabar, Ridwan Kamil: Semua Saya Doakan...
# 999        fikri_arif  @teddy_tjahjono @persib @PSSI @pt_lib @Kemenpo...
# 1000         sifoelan  Ridwan Kamil Pastikan Kereta Cepat Jakarta Ban...
#
#                     Location
# 0     Ujungberung, Indonesia
# 1                  Tangerang
# ...

# %%
tweets_df1.to_csv('twitter.csv', index=False)
